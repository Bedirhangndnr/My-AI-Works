# %% [markdown]
# **subject=**kişiler
#
# **timepoint=**zaman noktaları
#
# **event=**birbirinden farklı olaylar
#
# **region=**sinyal toplanan bölge
#
# **signal=**sinyal

# %%
import seaborn as sns

fmri = sns.load_dataset("fmri")
df = fmri.copy()
df.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
#diğerlerine göre daha zor problemlerde kullanılır. amana baglı degişkenlerin oldugu veri setlerinde, ve nesnelerin interneti gibi
#senaryolarda makinaların ürettiği verileri görselleştirmek için kullanılır.

# %%
df.shape
# Out:
# (1064, 5)

# %%
df["timepoint"].describe()
# Out:
# count    1064.000000
# mean        9.000000
# std         5.479801
# min         0.000000
# 25%         4.000000
# 50%         9.000000
# 75%        14.000000
# max        18.000000
# Name: timepoint, dtype: float64

# %%
df["signal"].describe()
# Out:
# count    1064.000000
# mean        0.003540
# std         0.093930
# min        -0.255486
# 25%        -0.046070
# 50%        -0.013653
# 75%         0.024293
# max         0.564985
# Name: signal, dtype: float64

# %%
df.groupby("timepoint")["signal"].count()
# Out:
# timepoint
# 0     56
# 1     56
# 2     56
# 3     56
# 4     56
# 5     56
# 6     56
# 7     56
# 8     56
# 9     56
# 10    56
# 11    56
# 12    56
# 13    56
# 14    56
# 15    56
# 16    56
# 17    56
# 18    56
# Name: signal, dtype: int64

# %%
df.groupby("signal").count()
# Out:
#            subject  timepoint  event  region
# signal
# -0.255486        1          1      1       1
# -0.238474        1          1      1       1
# -0.224351        1          1      1       1
# -0.181241        1          1      1       1
# -0.178510        1          1      1       1
# ...            ...        ...    ...     ...
#  0.455575        1          1      1       1
#  0.460896        1          1      1       1
#  0.476055        1          1      1       1
#  0.494787        1          1      1       1
#  0.564985        1          1      1       1
#
# [1064 rows x 4 columns]

# %%
df.groupby("timepoint")["signal"].describe()
# Out:
#            count      mean       std       min       25%       50%       75%  \
# timepoint
# 0           56.0 -0.016662  0.028326 -0.064454 -0.039169 -0.018382  0.003539
# 1           56.0 -0.025002  0.030641 -0.082174 -0.046299 -0.024533 -0.005388
# 2           56.0 -0.012873  0.035440 -0.110565 -0.034944 -0.013183  0.009318
# 3           56.0  0.034446  0.058260 -0.089708 -0.001157  0.028430  0.061840
# 4           56.0  0.098194  0.092838 -0.046347  0.030912  0.070166  0.144911
# 5           56.0  0.137725  0.123353 -0.017946  0.042762  0.096535  0.211638
# 6           56.0  0.127515  0.137332 -0.054405  0.022409  0.068850  0.218919
# 7           56.0  0.075660  0.129704 -0.108222 -0.016252  0.032486  0.144781
# 8           56.0  0.013420  0.104216 -0.181241 -0.049453 -0.012834  0.030396
# 9           56.0 -0.032041  0.072728 -0.152929 -0.075693 -0.038496  0.008717
# 10          56.0 -0.053685  0.053148 -0.176453 -0.078893 -0.052906 -0.015302
# ...

# %% [markdown]
# **çizgi grafiği olusturma**

# %%
sns.lineplot(x="timepoint",y="signal",data=df);

# %%
sns.lineplot(x="timepoint",y="signal",hue="event",data=df);

# %%
sns.lineplot(x="timepoint",y="signal",hue="event",style="event",data=df);

# %%
sns.lineplot(x="timepoint",
             y="signal",
             hue="event",
             style="event",
             markers=True, dashes=False,data=df);

# %%
sns.lineplot(x="timepoint",
             y="signal",
             hue="region",
             style="event",
             data=df);

# %%
# !pip install pandas_datareader
#pandas_datareader modülünün indirilmesi gerektiginden indirdik.
import pandas_datareader as pr

# %%
df=pr.get_data_yahoo("AAPL",start="2016-01-01",end="2019-08-25")
df.head()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2016-01-04  105.370003  102.000000  102.610001  105.349998  67649400.0
# 2016-01-05  105.849998  102.410004  105.750000  102.709999  55791000.0
# 2016-01-06  102.370003   99.870003  100.559998  100.699997  68457400.0
# 2016-01-07  100.129997   96.430000   98.680000   96.449997  81094400.0
# 2016-01-08   99.110001   96.760002   98.550003   96.959999  70798000.0
#
#             Adj Close
# Date
# 2016-01-04  97.948441
# 2016-01-05  95.493919
# 2016-01-06  93.625145
# 2016-01-07  89.673714
# 2016-01-08  90.147873

# %%
df.shape
# Out:
# (917, 6)

# %%
#kapanış degeri üzerinden gidelim
kapanis=df["Close"]
kapanis.head()
# Out:
# Date
# 2016-01-04    105.349998
# 2016-01-05    102.709999
# 2016-01-06    100.699997
# 2016-01-07     96.449997
# 2016-01-08     96.959999
# Name: Close, dtype: float64

# %%
kapanis.plot()

# %%
import pandas as pd
kapanis.index
# Out:
# DatetimeIndex(['2016-01-04', '2016-01-05', '2016-01-06', '2016-01-07',
#                '2016-01-08', '2016-01-11', '2016-01-12', '2016-01-13',
#                '2016-01-14', '2016-01-15',
#                ...
#                '2019-08-12', '2019-08-13', '2019-08-14', '2019-08-15',
#                '2019-08-16', '2019-08-19', '2019-08-20', '2019-08-21',
#                '2019-08-22', '2019-08-23'],
#               dtype='datetime64[ns]', name='Date', length=917, freq=None)

# %%
#alt satırdaki işlem, kapanis degerinin bir zaman degiskeni olduğunu bildirme işlemi idi
kapanis.index=pd.DatetimeIndex(kapanis.index)
kapanis.index
# Out:
# DatetimeIndex(['2016-01-04', '2016-01-05', '2016-01-06', '2016-01-07',
#                '2016-01-08', '2016-01-11', '2016-01-12', '2016-01-13',
#                '2016-01-14', '2016-01-15',
#                ...
#                '2019-08-12', '2019-08-13', '2019-08-14', '2019-08-15',
#                '2019-08-16', '2019-08-19', '2019-08-20', '2019-08-21',
#                '2019-08-22', '2019-08-23'],
#               dtype='datetime64[ns]', name='Date', length=917, freq=None)

# %%
kapanis.plot()
